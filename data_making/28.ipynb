# %%
from model.m25odel_2 import MultiDecoderCondVAE

# %%
import pandas as pd
df = pd.read_csv('211210-DRM-total.csv')
metal = df.iloc[:,2:25]
c_df = df.iloc[:,70:]

# %%
x_dim  = metal.shape[1]
c_dim = c_df.shape[1]

# %%
model = MultiDecoderCondVAE(x_dim,c_dim,z_dim = 7,z1_dim = 15)

# %%
# %pip install torchviz -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from torchviz import make_dot
y = model()
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# MultiDecoderCondVAE                      [1, 23]                   --
# ├─Sequential: 1-1                        [1, 64]                   --
# │    └─Linear: 2-1                       [1, 32]                   1,248
# │    └─ReLU: 2-2                         [1, 32]                   --
# │    └─Linear: 2-3                       [1, 64]                   2,112
# │    └─ReLU: 2-4                         [1, 64]                   --
# ├─Linear: 1-2                            [1, 7]                    455
# ├─Linear: 1-3                            [1, 7]                    455
# ├─Sequential: 1-4                        [1, 23]                   --
# │    └─Linear: 2-5                       [1, 64]                   1,472
# │    └─ReLU: 2-6                         [1, 64]                   --
# │    └─Linear: 2-7                       [1, 32]                   2,080
# ...
